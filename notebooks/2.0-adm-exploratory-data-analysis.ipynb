# %% [markdown]
# # Exploratory data analysis
#
# Finding the odd groupings of the data.
#
# ---

# %%
# %run 1.0-adm-load-data-2012.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Variables now available: df

# %% [markdown]
# ---
#
# ## Summary of the data

# %% [markdown]
# ### Shape

# %%
n_rows, n_cols = df.shape
print("We are analysing {} respondents' answers to {} questions.".format(n_rows, n_cols))
# Out:
# We are analysing 5914 respondents' answers to 31 questions.

# %% [markdown]
# ### Column names

# %%
df.columns
# Out:
# Index(['campfin_limcorp', 'pid_self', 'spsrvpr_ssself', 'defsppr_self',
#        'inspre_self', 'gun_control', 'guarpr_self', 'immig_policy',
#        'aidblack_self', 'envjob_self', 'aa_uni', 'fedspend_ss',
#        'fedspend_schools', 'fedspend_scitech', 'fedspend_crime',
#        'fedspend_welfare', 'envir_gwarm', 'gayrt_marry', 'penalty_favdpen',
#        'relig_churchoft', 'dem_edu', 'dem_veteran', 'budget_rdefctax',
#        'budget_rdefmil', 'patriot_amident', 'milln_milltax', 'budget_rdef250k',
#        'fairjob_opin', 'immigpo_jobs', 'wiretap_warrant', 'postvote_presvt'],
#       dtype='object')

# %% [markdown]
# ### Data types
#
# They're all floats to include the missing value, `np.nan`.

# %%
df.dtypes
# Out:
# campfin_limcorp     float64
# pid_self            float64
# spsrvpr_ssself      float64
# defsppr_self        float64
# inspre_self         float64
# gun_control         float64
# guarpr_self         float64
# immig_policy        float64
# aidblack_self       float64
# envjob_self         float64
# aa_uni              float64
# fedspend_ss         float64
# fedspend_schools    float64
# fedspend_scitech    float64
# fedspend_crime      float64
# fedspend_welfare    float64
# envir_gwarm         float64
# gayrt_marry         float64
# penalty_favdpen     float64
# relig_churchoft     float64
# dem_edu             float64
# dem_veteran         float64
# budget_rdefctax     float64
# budget_rdefmil      float64
# patriot_amident     float64
# milln_milltax       float64
# budget_rdef250k     float64
# fairjob_opin        float64
# immigpo_jobs        float64
# wiretap_warrant     float64
# postvote_presvt     float64
# dtype: object

# %% [markdown]
# ### Missing values by column

# %%
df.isnull().sum()
# Out:
# campfin_limcorp      122
# pid_self             319
# spsrvpr_ssself       673
# defsppr_self         727
# inspre_self          443
# gun_control           25
# guarpr_self          438
# immig_policy          47
# aidblack_self        726
# envjob_self          909
# aa_uni                86
# fedspend_ss           64
# fedspend_schools      33
# fedspend_scitech      62
# fedspend_crime        53
# fedspend_welfare      66
# envir_gwarm          138
# gayrt_marry           80
# penalty_favdpen      162
# relig_churchoft     2376
# dem_edu               68
# dem_veteran            4
# budget_rdefctax      481
# budget_rdefmil       454
# patriot_amident      422
# milln_milltax        437
# budget_rdef250k      444
# fairjob_opin         999
# immigpo_jobs         463
# wiretap_warrant      476
# postvote_presvt     1916
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, orient='h');

# %%
sns.countplot(hue=df.pid_self, x=df.relig_churchoft, palette="RdBu");

# %%
sns.countplot(df.dem_edu.dropna());

# %% [markdown]
# The education distribution isn't pretty. It's bimodal. The two big lumps are:
#
# * 9 and 10: High school graduate or some college
# * 13: Bachelor's degree
#
# Since our imputation strategy relies on the assumption of a normal distribution, we're in some hot water here.

# %%
sns.countplot(df.campfin_limcorp.dropna());
